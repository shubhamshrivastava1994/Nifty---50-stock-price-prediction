# %%
# !pip install gspread

# %%
import pandas as pd
import numpy as np
import gspread

# %%
gc=gspread.service_account('investment-advisor-366115-334faf7c1443.json')

# %%
gc

# %%
df=gc.open('new_income/expence')
df
# Out:
# <Spreadsheet 'new_income/expence' id:14fX4Zwfm3K0ebTcDg4Gh1CGsyWWTwjO67z0mSHw7QAM>

# %%
wks=df.worksheet('Sheet1')
wks
# Out:
# <Worksheet 'Sheet1' id:0>

# %%
data=wks.get_all_records()
data
# Out:
# [{'Date': '3/2/2022 10:11',
#   'Account1': 'CUB - online payment',
#   'Category': 'Food',
#   'Subcategory': '',
#   'Note1': 'Brownie',
#   'INR': 50,
#   'Income/Expense': 'Expense',
#   'Note': '',
#   'Amount': 50,
#   'Currency': 'INR',
#   'Account': 50},
#  {'Date': '3/2/2022 10:11',
#   'Account1': 'CUB - online payment',
#   'Category': 'Other',
#   'Subcategory': '',
#   'Note1': 'To lended people',
#   'INR': 100,
#   'Income/Expense': 'Expense',
#   'Note': '',
#   'Amount': 100,
#   'Currency': 'INR',
#   'Account': 100},
#  {'Date': '3/1/2022 19:50',
#   'Account1': 'CUB - online payment',
#   'Category': 'Food',
#   'Subcategory': '',
#   'Note1': 'Dinner',
#   'INR': 78,
#   'Income/Expense': 'Expense',
#   'Note': '',
#   'Amount': 78,
#   'Currency': 'INR',
#   'Account': 78},
#  {'Date': '3/1/2022 18:56',
#   'Account1': 'CUB - online payment',
#   'Category': 'Transportation',
#   'Subcategory': '',
#   'Note1': 'Metro',
#   'INR': 30,
# ...

# %%
df=pd.DataFrame(data)
df
# Out:
#                  Date              Account1        Category Subcategory  \
# 0      3/2/2022 10:11  CUB - online payment            Food
# 1      3/2/2022 10:11  CUB - online payment           Other
# 2      3/1/2022 19:50  CUB - online payment            Food
# 3      3/1/2022 18:56  CUB - online payment  Transportation
# 4      3/1/2022 18:22  CUB - online payment            Food
# ..                ...                   ...             ...         ...
# 271  11/23/2021 22:53  CUB - online payment            Food
# 272  11/22/2021 14:16  CUB - online payment            Food
# 273  11/22/2021 14:16  CUB - online payment            Food
# 274  11/21/2021 17:07  CUB - online payment  Transportation
# 275  11/21/2021 15:50  CUB - online payment            Food
#
#                   Note1  INR Income/Expense Note  Amount Currency  Account
# 0               Brownie   50        Expense           50      INR       50
# ...

# %% [markdown]
# # subtask1

# %%
len(df)
# Out:
# 276

# %%
value=df['INR']

# %%
new=df["Income/Expense"]

# %%
sum1=0
l=len(df)    
for i in range(l):
    if new[i]=="Expense":
        sum1=sum1+value[i]
print('Expense is {}'.format(round(sum1)))
# Out:
# Expense is 56744

# %%
sum2=0
l=len(df)    
for i in range(l):
    if new[i]=="Income":
        sum2=sum2+value[i]
print('Income is {}'.format(round(sum2)))
# Out:
# Income is 73749

# %%
q=df['Category']
q
# Out:
# 0                Food
# 1               Other
# 2                Food
# 3      Transportation
# 4                Food
#             ...
# 271              Food
# 272              Food
# 273              Food
# 274    Transportation
# 275              Food
# Name: Category, Length: 276, dtype: object

# %%
df[df['Category']=='Allowance']
# Out:
#                  Date              Account1   Category Subcategory     Note1  \
# 152    1/1/2022 21:45  CUB - online payment  Allowance              From dad
# 191  12/18/2021 21:00  CUB - online payment  Allowance              From dad
# 208  12/11/2021 09:22  CUB - online payment  Allowance              From dad
# 228   12/5/2021 12:23  CUB - online payment  Allowance              From dad
# 237   12/3/2021 21:28  CUB - online payment  Allowance              From dad
# 255  11/27/2021 13:46  CUB - online payment  Allowance              From dad
#
#       INR Income/Expense Note  Amount Currency  Account
# 152  1000         Income         1000      INR     1000
# 191  1000         Income         1000      INR     1000
# 208  1000         Income         1000      INR     1000
# 228  8000         Income         8000      INR     8000
# 237  1000         Income         1000      INR     1000
# 255  2000         Income         2000      INR     2000

# %%
value=df['INR']
value
# Out:
# 0       50
# 1      100
# 2       78
# 3       30
# 4       67
#       ...
# 271    179
# 272     90
# 273     97
# 274    130
# 275    875
# Name: INR, Length: 276, dtype: int64

# %%
x=list(set(df["Category"]))
length = len(x)
dic={}
for i in x:
    sum=0
    for j in range(len(df)):
        if q[j]==i:
            sum=sum+value[j]
    print(i,sum)
    dic[i]=sum
# Out:
# Petty cash 3
# Self-development 400
# Gift 115
# Beauty 196
# Salary 20000
# Allowance 14000
# Transportation 8504
# Social Life 2514
# Food 23421
# Other 44663
# Apparel 3089
# Household 12188
# Education 1400

# %% [markdown]
# # Available for investment

# %%
AVI=sum2-sum1
print("Available for investment",':',AVI)
# Out:
# Available for investment : 17005

# %% [markdown]
# # CONNECTING FINAL REPORT

# %%
df1=gc.open('new_final report')

# %%
df1
# Out:
# <Spreadsheet 'new_final report' id:1irYGqAM1UP7zT095HoQjG8j1DvJcz4sYoUw2QWGRAT0>

# %%
sheet=df1.sheet1
sheet
# Out:
# <Worksheet 'Sheet1' id:0>

# %% [markdown]
# # UPDATE FINAL REPORT

# %%
r=sheet.find('Net Income').row
c=sheet.find('Net Income').col
print(r,c)
# Out:
# 7 2

# %%
sheet.update_cell(r,c+1,int(sum2))
# Out:
# {'spreadsheetId': '1irYGqAM1UP7zT095HoQjG8j1DvJcz4sYoUw2QWGRAT0',
#  'updatedRange': 'Sheet1!C7',
#  'updatedRows': 1,
#  'updatedColumns': 1,
#  'updatedCells': 1}

# %%
r=sheet.find('Net Expense').row
c=sheet.find('Net Expense').col
print(r,c)
# Out:
# 8 2

# %%
sheet.update_cell(r,c+1,int(sum1))
# Out:
# {'spreadsheetId': '1irYGqAM1UP7zT095HoQjG8j1DvJcz4sYoUw2QWGRAT0',
#  'updatedRange': 'Sheet1!C8',
#  'updatedRows': 1,
#  'updatedColumns': 1,
#  'updatedCells': 1}

# %% [markdown]
# # UPDATE CATEGORY VALUE TO FINAL REPORT

# %%
dic
# Out:
# {'Petty cash': 3,
#  'Self-development': 400,
#  'Gift': 115,
#  'Beauty': 196,
#  'Salary': 20000,
#  'Allowance': 14000,
#  'Transportation': 8504,
#  'Social Life': 2514,
#  'Food': 23421,
#  'Other': 44663,
#  'Apparel': 3089,
#  'Household': 12188,
#  'Education': 1400}

# %%
for i in dic:
    r=sheet.find(i).row
    c=sheet.find(i).col
    sheet.update_cell(r,c+1,int(dic[i]))

# %%
r=sheet.find('Food').row
c=sheet.find('Food').col
print(r,c)
# Out:
# 10 2

# %%
r=sheet.find('Available for investment').row
c=sheet.find('Available for investment').col
print(r,c)
# Out:
# 24 2

# %%
sheet.update_cell(r,c+1,int(AVI))
# Out:
# {'spreadsheetId': '1irYGqAM1UP7zT095HoQjG8j1DvJcz4sYoUw2QWGRAT0',
#  'updatedRange': 'Sheet1!C24',
#  'updatedRows': 1,
#  'updatedColumns': 1,
#  'updatedCells': 1}

# %% [markdown]
# # Subtask - 2:

# %%
gc.open('new_bse500')
# Out:
# <Spreadsheet 'new_bse500' id:1MxCPFm6HcKegqlINpGqeiZup2p1kQFCnWNX4CUeVVw4>

# %%
data1=gc.open('new_bse500')
data1
# Out:
# <Spreadsheet 'new_bse500' id:1MxCPFm6HcKegqlINpGqeiZup2p1kQFCnWNX4CUeVVw4>

# %%
gsheet=data1.sheet1
gsheet
# Out:
# <Worksheet 'Sheet1' id:0>

# %%
gc1=gsheet.get_all_records()
gc1
# Out:
# [{'Company': 'Sanofi India Ltd.',
#   'BSE code': 500674,
#   'NSE code': 'SANOFI',
#   'ISIN': 'INE058A01010',
#   'Sector': 'Healthcare',
#   'Industry': 'Drugs & Pharma',
#   'Date': '2022-09-05',
#   'Price': 6158.7,
#   '1 day change(%)': 0.59,
#   '52 Week Low': 6086.3,
#   '52 Week High': 8542.75,
#   '3 Year Low': 5607.0,
#   '3 Year High': 9300.0,
#   '5 Year Low': 3901.0,
#   '5 Year High': 9300.0,
#   'All Time Low': 235.05,
#   'All Time High': 9300.0,
#   'Market Cap(Cr)': 14189.17,
#   'Enterprise Value(Cr)': 12556.76,
#   '1-Week Return': -1.36,
#   '1-Month Return': -6.6,
#   '3-Month Return(%)': -10.19,
#   '1-Year Return(%)': -26.69,
#   '3-Year Return': 0.16,
#   '5-Year Return(%)': 8.88,
#   '10-Year Return(%)': 10.97,
#   'Price to Earnings': 14.49,
#   'Median P/E': 35.91,
#   'Price to Book': 9.75,
#   'Median P/B': 6.71,
#   'Earning Yield(%)': 6.15,
#   'Price earnings to growth': 0.49,
#   'Dividend Yield(%)': 7.95,
#   'EV / EBITDA': 16.68,
# ...

# %%
df2=pd.DataFrame(gc1)
df2
# Out:
#                                          Company  BSE code    NSE code  \
# 0                              Sanofi India Ltd.    500674      SANOFI
# 1                           Page Industries Ltd.    532827     PAGEIND
# 2    Procter & Gamble Hygiene & Health Care Ltd.    500459        PGHH
# 3                              Abbott India Ltd.    500488  ABBOTINDIA
# 4                                     Bosch Ltd.    500530    BOSCHLTD
# ..                                           ...       ...         ...
# 496                    Westlife Development Ltd.    505533    WESTLIFE
# 497                               Wockhardt Ltd.    532300  WOCKPHARMA
# 498                                Yes Bank Ltd.    532648     YESBANK
# 499                                  Zomato Ltd.    543320      ZOMATO
# 500                              Tata Motors DVR    570001  TATAMTRDVR
#
#              ISIN            Sector                       Industry  \
# ...

# %% [markdown]
# # USING FUNCTION TO CLEAN DATA

# %%
df2['3 Year Low']=df2['3 Year Low'].replace({',':''},regex=True).apply(pd.to_numeric,1)

# %%
df2['3 Year High'] = df2['3 Year High'].replace({',':''},regex=True).apply(pd.to_numeric,1)

# %%
df2['5 Year Low']=df2['5 Year Low'].replace({',':''},regex=True).apply(pd.to_numeric,1)

# %%
df2['5 Year High'] = df2['5 Year High'].replace({',':''},regex=True).apply(pd.to_numeric,1)

# %%
df2['All Time Low'] = df2['All Time Low'].replace({',':''},regex=True).apply(pd.to_numeric,1)

# %%
df2['All Time High'] = df2['All Time High'].replace({',':''},regex=True).apply(pd.to_numeric,1)

# %%
df2['Enterprise Value(Cr)'] = df2['Enterprise Value(Cr)'].replace({',':''},regex=True).apply(pd.to_numeric,1)

# %%
df2['Market Cap(Cr)'] = df2['Market Cap(Cr)'].replace({',':''},regex=True).apply(pd.to_numeric,1)

# %%
df2['Earning Yield(%)'] = df2['Earning Yield(%)'].replace({',':''},regex=True).apply(pd.to_numeric,1)

# %%
df2['Price / Cash Flow'] = df2['Price / Cash Flow'].replace({',':''},regex=True).apply(pd.to_numeric,1)

# %%
df2['Earning Per Share'] = df2['Earning Per Share'].replace({',':''},regex=True).apply(pd.to_numeric,1)

# %%
df2['Book Value Per Share'] = df2['Book Value Per Share'].replace({',':''},regex=True).apply(pd.to_numeric,1)

# %%
df2['Cash Flow Per Share'] = df2['Cash Flow Per Share'].replace({',':''},regex=True).apply(pd.to_numeric,1)

# %%
df2['Dividend Per Share'] = df2['Dividend Per Share'].replace({',':''},regex=True).apply(pd.to_numeric,1)

# %%
df2['Dividend Per Share'] = df2['Dividend Per Share'].replace({',':''},regex=True).apply(pd.to_numeric,1)

# %%
df2['Price / Sales'] = df2['Price / Sales'].replace({',':''},regex=True).apply(pd.to_numeric,1)

# %%
df2['EV / EBITDA'] = df2['EV / EBITDA'].replace({',':''},regex=True).apply(pd.to_numeric,1)

# %%
df2['Price earnings to growth'] = df2['Price earnings to growth'].replace({',':''},regex=True).apply(pd.to_numeric,1)

# %%
df2['3-Year Return'] = df2['3-Year Return'].replace({',':''},regex=True).apply(pd.to_numeric,1)

# %%
df2['5-Year Return(%)'] = df2['5-Year Return(%)'].replace({',':''},regex=True).apply(pd.to_numeric,1)

# %%
df2['10-Year Return(%)'] = df2['10-Year Return(%)'].replace({',':''},regex=True).apply(pd.to_numeric,1)

# %%
df2['Price to Earnings'] = df2['Price to Earnings'].replace({',':''},regex=True).apply(pd.to_numeric,1)

# %%
df2['Median P/E'] = df2['Median P/E'].replace({',':''},regex=True).apply(pd.to_numeric,1)

# %%
df2['Price to Book'] = df2['Price to Book'].replace({',':''},regex=True).apply(pd.to_numeric,1)

# %%
df2['Median P/B'] = df2['Median P/B'].replace({',':''},regex=True).apply(pd.to_numeric,1)

# %%
df2['Dividend Per Share'] = df2['Dividend Per Share'].replace({',':''},regex=True).apply(pd.to_numeric,1)

# %%
df2['52 Week High'] = df2['52 Week High'].replace({',':''},regex=True).apply(pd.to_numeric,1)

# %%
df2['Price']=df2['Price'].replace({',':''},regex=True).apply(pd.to_numeric,1)

# %%
df2['52 Week Low'] = df2['52 Week High'].replace({',':''},regex=True).apply(pd.to_numeric,1)

# %%
df2.fillna(0, inplace = True)

# %% [markdown]
# # HIGH RISK TAKING

# %%
Com=df2[((df2['52 Week High'] - df2['Price'])/df2['52 Week Low'])>0]
Com
# Out:
#                                          Company  BSE code    NSE code  \
# 0                              Sanofi India Ltd.    500674      SANOFI
# 1                           Page Industries Ltd.    532827     PAGEIND
# 2    Procter & Gamble Hygiene & Health Care Ltd.    500459        PGHH
# 3                              Abbott India Ltd.    500488  ABBOTINDIA
# 4                                     Bosch Ltd.    500530    BOSCHLTD
# ..                                           ...       ...         ...
# 496                    Westlife Development Ltd.    505533    WESTLIFE
# 497                               Wockhardt Ltd.    532300  WOCKPHARMA
# 498                                Yes Bank Ltd.    532648     YESBANK
# 499                                  Zomato Ltd.    543320      ZOMATO
# 500                              Tata Motors DVR    570001  TATAMTRDVR
#
#              ISIN            Sector                       Industry  \
# ...

# %%
HRT=Com[Com['Market Cap(Cr)']<4000]
HRT
# Out:
#                                 Company  BSE code    NSE code          ISIN  \
# 92          Thyrocare Technologies Ltd.    539871   THYROCARE  INE594H01019
# 99                Dhanuka Agritech Ltd.    507717     DHANUKA  INE435G01025
# 190                           MOIL Ltd.    533286        MOIL  INE490G01020
# 213  Sudarshan Chemical Industries Ltd.    506655  SUDARSCHEM  INE659A01023
# 267                          Nesco Ltd.    505355       NESCO  INE317F01035
# 278             Mishra Dhatu Nigam Ltd.    541195     MIDHANI  INE099Z01011
# 300                Indoco Remedies Ltd.    532612      INDOCO  INE873D01024
# 319             Mahindra Logistics Ltd.    540768      MAHLOG  INE766P01016
# 342                    La Opala RG Ltd.    526947     LAOPALA  INE059D01020
# 356                Shilpa Medicare Ltd.    530549   SHILPAMED  INE790G01031
# 359   Advanced Enzyme Technologies Ltd.    540025  ADVENZYMES  INE837H01020
# ...

# %%
HRT=HRT[Com['10-Year Return(%)']<8]
HRT
# Out:
# C:\Users\ABC\AppData\Local\Temp\ipykernel_6508\3776718209.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   HRT=HRT[Com['10-Year Return(%)']<8]
#                                Company  BSE code    NSE code          ISIN  \
# 92         Thyrocare Technologies Ltd.    539871   THYROCARE  INE594H01019
# 190                          MOIL Ltd.    533286        MOIL  INE490G01020
# 278            Mishra Dhatu Nigam Ltd.    541195     MIDHANI  INE099Z01011
# 319            Mahindra Logistics Ltd.    540768      MAHLOG  INE766P01016
# 359  Advanced Enzyme Technologies Ltd.    540025  ADVENZYMES  INE837H01020
# 364                Dilip Buildcon Ltd.    540047         DBL  INE917M01012
# 400         Responsive Industries Ltd.    505509   RESPONIND  INE688D01026
# 404                     Vakrangee Ltd.    511431   VAKRANGEE  INE051B01021
# 425                      CSB Bank Ltd.    542867     CSBBANK  INE679A01013
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501 entries, 0 to 500
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Company                   501 non-null    object
#  1   BSE code                  501 non-null    int64
#  2   NSE code                  501 non-null    object
#  3   ISIN                      501 non-null    object
#  4   Sector                    501 non-null    object
#  5   Industry                  501 non-null    object
#  6   Date                      501 non-null    object
#  7   Price                     501 non-null    float64
#  8   1 day change(%)           501 non-null    float64
#  9   52 Week Low               501 non-null    float64
#  10  52 Week High              501 non-null    float64
#  11  3 Year Low                501 non-null    float64
#  12  3 Year High               501 non-null    float64
# ...

# %%
comHRT=(HRT.sort_values('Dividend Per Share',ascending=False).head(5))['Company']

# %%
list1=[]
for i in comHRT:
    list1.append(i)
print(list1)
# Out:
# ['Thyrocare Technologies Ltd.', 'MOIL Ltd.', 'Mishra Dhatu Nigam Ltd.', 'Mahindra Logistics Ltd.', 'Advanced Enzyme Technologies Ltd.']

# %% [markdown]
# # RISK TAKING

# %%
Com=df2[((df2['52 Week High']-df2['Price'])/df2['52 Week Low'])>0]
Com
# Out:
#                                          Company  BSE code    NSE code  \
# 0                              Sanofi India Ltd.    500674      SANOFI
# 1                           Page Industries Ltd.    532827     PAGEIND
# 2    Procter & Gamble Hygiene & Health Care Ltd.    500459        PGHH
# 3                              Abbott India Ltd.    500488  ABBOTINDIA
# 4                                     Bosch Ltd.    500530    BOSCHLTD
# ..                                           ...       ...         ...
# 496                    Westlife Development Ltd.    505533    WESTLIFE
# 497                               Wockhardt Ltd.    532300  WOCKPHARMA
# 498                                Yes Bank Ltd.    532648     YESBANK
# 499                                  Zomato Ltd.    543320      ZOMATO
# 500                              Tata Motors DVR    570001  TATAMTRDVR
#
#              ISIN            Sector                       Industry  \
# ...

# %%
RT = Com[(Com['Market Cap(Cr)']>4000) & (Com['Market Cap(Cr)']<8000)]
RT
# Out:
#                                        Company  BSE code    NSE code  \
# 10                         VST Industries Ltd.    509966      VSTIND
# 11                Procter & Gamble Health Ltd.    500126        PGHL
# 18                   Maharashtra Scooters Ltd.    500266  MAHSCOOTER
# 22                             Esab India Ltd.    500133   ESABINDIA
# 42                                    HEG Ltd.    509631         HEG
# ..                                         ...       ...         ...
# 486  Sun Pharma Advanced Research Company Ltd.    532872       SPARC
# 490                      TCNS Clothing Co Ltd.    541700  TCNSBRANDS
# 491                    TeamLease Services Ltd.    539658   TEAMLEASE
# 492                        TV18 Broadcast Ltd.    532800  TV18BRDCST
# 494                    Varroc Engineering Ltd.    541578      VARROC
#
#              ISIN            Sector               Industry        Date  \
# ...

# %%
RT = RT[(RT['10-Year Return(%)']>8) & (RT['10-Year Return(%)']<10) ]
RT
# Out:
#                                         Company  BSE code    NSE code  \
# 138     The Great Eastern Shipping Company Ltd.    500620      GESHIP
# 286                            Jyothy Labs Ltd.    532926   JYOTHYLAB
# 303  Gujarat State Fertilizers & Chemicals Ltd.    500690        GSFC
# 325                            Tata Coffee Ltd.    532301  TATACOFFEE
# 395          Shipping Corporation Of India Ltd.    523598         SCI
# 461       Mahindra Holidays & Resorts India Ltd    533088       MHRIL
# 472                          Prism Johnson Ltd.    500338  PRSMJOHNSN
#
#              ISIN            Sector                       Industry  \
# 138  INE017A01032          Services                       Shipping
# 286  INE668F01031  Consumer Staples  Household & Personal Products
# 303  INE026A01025         Chemicals        Nitrogenous Fertilizer.
# 325  INE493A01027  Consumer Staples                   Tea & Coffee
# 395  INE109A01011          Services                       Shipping
# ...

# %%
comRT=(RT.sort_values('Dividend Per Share',ascending=False).head(5))['Company']
comRT
# Out:
# 138       The Great Eastern Shipping Company Ltd.
# 286                              Jyothy Labs Ltd.
# 303    Gujarat State Fertilizers & Chemicals Ltd.
# 325                              Tata Coffee Ltd.
# 395            Shipping Corporation Of India Ltd.
# Name: Company, dtype: object

# %%
list2=[]
for i in comRT:
    list2.append(i)
list2
# Out:
# ['The Great Eastern Shipping Company Ltd.',
#  'Jyothy Labs Ltd.',
#  'Gujarat State Fertilizers & Chemicals Ltd.',
#  'Tata Coffee Ltd.',
#  'Shipping Corporation Of India Ltd.']

# %% [markdown]
# # MODERATE RISK TAKING

# %%
Com=df2[((df2['52 Week High']-df2['Price'])/df2['52 Week Low'])>0]
Com
# Out:
#                                          Company  BSE code    NSE code  \
# 0                              Sanofi India Ltd.    500674      SANOFI
# 1                           Page Industries Ltd.    532827     PAGEIND
# 2    Procter & Gamble Hygiene & Health Care Ltd.    500459        PGHH
# 3                              Abbott India Ltd.    500488  ABBOTINDIA
# 4                                     Bosch Ltd.    500530    BOSCHLTD
# ..                                           ...       ...         ...
# 496                    Westlife Development Ltd.    505533    WESTLIFE
# 497                               Wockhardt Ltd.    532300  WOCKPHARMA
# 498                                Yes Bank Ltd.    532648     YESBANK
# 499                                  Zomato Ltd.    543320      ZOMATO
# 500                              Tata Motors DVR    570001  TATAMTRDVR
#
#              ISIN            Sector                       Industry  \
# ...

# %%
MRT = Com[(Com['Market Cap(Cr)']>8000) & (Com['Market Cap(Cr)']<12000)]
MRT
# Out:
#                                    Company  BSE code    NSE code  \
# 19                   Akzo Nobel India Ltd.    500710   AKZOINDIA
# 27        Tata Investment Corporation Ltd.    501301  TATAINVEST
# 36                   Sundaram-Clayton Ltd.    520056  SUNCLAYLTD
# 44   Computer Age Management Services Ltd.    543232        CAMS
# 61                          Angel One Ltd.    543235    ANGELONE
# ..                                     ...       ...         ...
# 477              Sapphire Foods India Ltd.    543397    SAPPHIRE
# 479               Shree Renuka Sugars Ltd.    532670      RENUKA
# 487                     Suzlon Energy Ltd.    532667      SUZLON
# 496              Westlife Development Ltd.    505533    WESTLIFE
# 500                        Tata Motors DVR    570001  TATAMTRDVR
#
#              ISIN            Sector              Industry        Date  \
# 19   INE133A01011         Materials    Paints & Varnishes  2022-09-05
# ...

# %%
MRT = MRT[(MRT['10-Year Return(%)']>15) & (MRT['10-Year Return(%)']<20) ]
MRT
# Out:
#                                 Company  BSE code   NSE code          ISIN  \
# 64                          Cyient Ltd.    532175     CYIENT  INE136B01020
# 174                Redington India Ltd.    532805  REDINGTON  INE891D01026
# 219                 Zydus Wellness Ltd.    531335  ZYDUSWELL  INE768C01010
# 255             Allcargo Logistics Ltd.    532749   ALLCARGO  INE418H01029
# 288        Mahindra CIE Automotive Ltd.    532756  MAHINDCIE  INE536H01010
# 318  Mahindra Lifespace Developers Ltd.    532313    MAHLIFE  INE813A01018
# 450                            ITI Ltd.    523610        ITI  INE248A01017
#
#                Sector                 Industry        Date    Price  \
# 64         Technology                 Software  2022-09-05   835.20
# 174          Services                  Trading  2022-09-05   150.00
# 219  Consumer Staples          Food Processing  2022-09-05  1634.00
# 255          Services                Logistics  2022-09-05   338.10
# ...

# %%
comMRT=(MRT.sort_values('Dividend Per Share',ascending=False).head(5))['Company']
comMRT
# Out:
# 64                      Cyient Ltd.
# 174            Redington India Ltd.
# 219             Zydus Wellness Ltd.
# 255         Allcargo Logistics Ltd.
# 288    Mahindra CIE Automotive Ltd.
# Name: Company, dtype: object

# %%
list3=[]
for i in comMRT:
    list3.append(i)
list3
# Out:
# ['Cyient Ltd.',
#  'Redington India Ltd.',
#  'Zydus Wellness Ltd.',
#  'Allcargo Logistics Ltd.',
#  'Mahindra CIE Automotive Ltd.']

# %% [markdown]
# # low risk taking

# %%
Com=df2[((df2['52 Week High']-df2['Price'])/df2['52 Week Low'])>0]
Com
# Out:
#                                          Company  BSE code    NSE code  \
# 0                              Sanofi India Ltd.    500674      SANOFI
# 1                           Page Industries Ltd.    532827     PAGEIND
# 2    Procter & Gamble Hygiene & Health Care Ltd.    500459        PGHH
# 3                              Abbott India Ltd.    500488  ABBOTINDIA
# 4                                     Bosch Ltd.    500530    BOSCHLTD
# ..                                           ...       ...         ...
# 496                    Westlife Development Ltd.    505533    WESTLIFE
# 497                               Wockhardt Ltd.    532300  WOCKPHARMA
# 498                                Yes Bank Ltd.    532648     YESBANK
# 499                                  Zomato Ltd.    543320      ZOMATO
# 500                              Tata Motors DVR    570001  TATAMTRDVR
#
#              ISIN            Sector                       Industry  \
# ...

# %%
LRT = Com[(Com['Market Cap(Cr)']>12000)]
LRT
# Out:
#                                          Company  BSE code    NSE code  \
# 0                              Sanofi India Ltd.    500674      SANOFI
# 1                           Page Industries Ltd.    532827     PAGEIND
# 2    Procter & Gamble Hygiene & Health Care Ltd.    500459        PGHH
# 3                              Abbott India Ltd.    500488  ABBOTINDIA
# 4                                     Bosch Ltd.    500530    BOSCHLTD
# ..                                           ...       ...         ...
# 489         Tata Teleservices (Maharashtra) Ltd.    532371        TTML
# 493                                     UCO Bank    532505     UCOBANK
# 495                           Vodafone Idea Ltd.    532822        IDEA
# 498                                Yes Bank Ltd.    532648     YESBANK
# 499                                  Zomato Ltd.    543320      ZOMATO
#
#              ISIN            Sector                       Industry  \
# ...

# %%
LRT = LRT[(LRT['10-Year Return(%)']>20)]
LRT
# Out:
#                                   Company  BSE code    NSE code          ISIN  \
# 1                    Page Industries Ltd.    532827     PAGEIND  INE761H01022
# 3                       Abbott India Ltd.    500488  ABBOTINDIA  INE358A01014
# 8                                MRF Ltd.    500290         MRF  INE883A01011
# 13       Bajaj Holdings & Investment Ltd.    500490  BAJAJHLDNG  INE118A01012
# 16        Honeywell Automation India Ltd.    517174      HONAUT  INE671A01010
# ..                                    ...       ...         ...           ...
# 388                          Trident Ltd.    521064     TRIDENT  INE064C01022
# 398                        KPR Mills Ltd.    532889     KPRMILL  INE930H01031
# 408                      Adani Power Ltd.    533096  ADANIPOWER  INE814H01011
# 476            Ruchi Soya Industries Ltd.    500368   PATANJALI  INE619A01035
# 489  Tata Teleservices (Maharashtra) Ltd.    532371        TTML  INE517B01013
#
# ...

# %%
comLRT=(LRT.sort_values('Dividend Per Share',ascending=False).head(5))['Company']
comLRT
# Out:
# 1                 Page Industries Ltd.
# 3                    Abbott India Ltd.
# 8                             MRF Ltd.
# 13    Bajaj Holdings & Investment Ltd.
# 16     Honeywell Automation India Ltd.
# Name: Company, dtype: object

# %%
list4=[]
for i in comLRT:
    list4.append(i)
list4
# Out:
# ['Page Industries Ltd.',
#  'Abbott India Ltd.',
#  'MRF Ltd.',
#  'Bajaj Holdings & Investment Ltd.',
#  'Honeywell Automation India Ltd.']

# %% [markdown]
# # EXTRACT INVESTEMENT PROFILE

# %%
Investment_Profile = sheet.acell('C27').value
Investment_Profile
# Out:
# 'Risk Taking'

# %% [markdown]
# # SHEET2 FINAL REPORT

# %%
data3 = gc.open("new_final report")

# %%
sheet2 = data3.worksheet("Sheet2")

# %% [markdown]
# # MAKING A DICT FOR COMPANY

# %%
dic = {'High Risk Taking':list1,'Risk Taking':list2,'Moderate Risk Taking':list3,
      'Low Risk Taking':list4}

# %%
Investment_Profile

show = dic[Investment_Profile]
show
# Out:
# ['The Great Eastern Shipping Company Ltd.',
#  'Jyothy Labs Ltd.',
#  'Gujarat State Fertilizers & Chemicals Ltd.',
#  'Tata Coffee Ltd.',
#  'Shipping Corporation Of India Ltd.']

# %%
r=sheet2.find('Investment Company').row
c=sheet2.find('Investment Company').col
r,c
# Out:
# (1, 2)

# %%
row=r+1
col=c
for i in show:
    sheet2.update_cell(row,col,i)
    row+=1

# %% [markdown]
# # AMOUNT TO BE INVESTED

# %%
x = AVI/5
x
# Out:
# 3401.0

# %%
r=sheet2.find('Amount to be invested').row
c=sheet2.find('Amount to be invested').col
r,c
# Out:
# (1, 3)

# %%
for i in range(r+1,r+6):
    sheet2.update_cell(i,c,int(x))
